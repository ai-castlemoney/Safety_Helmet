# %%
import pandas as pd

case = pd.read_csv('1. EDA_컬럼분할, 제거.csv', header = 0, index_col = 0)
case.head()
# Out:
#                                            사고명                     기상상태  \
# 1                           외남동162 근린생활시설 신축공사  날씨 : 맑음기온 : 23℃습도 : 20%
# 2  보라동 391-23 근린생활시설 및 다세대주택 신축공사 작업 착수 전 사망사고  날씨 : 흐림기온 : 22℃습도 : 50%
# 3                        송산그린시티 EB4블록 형틀공 추락사고  날씨 : 흐림기온 : 15℃습도 : 74%
# 4                             화성비봉 공공주택지구 조성공사  날씨 : 맑음기온 : 15℃습도 : 51%
# 5                         상도동 243-19 신축공사 추락사고  날씨 : 흐림기온 : 19℃습도 : 25%
#
#                                             시설물 종류                   인적사고  \
# 1  건축 - 건축물 - 근린생활시설(연면적 : 455.46㎡, 지상 2층, 지하 0층)                  물체에 맞음
# 2    건축 - 건축물 - 공동주택(연면적 : 709.85㎡, 지상 5층, 지하 0층)                      질병
# 3   건축 - 건축물 - 기타(연면적 : 24,161.30㎡, 지상 3층, 지하 1층)                      찔림
# 4                                   토목 - 기타 - 부지조성                     질병
# 5    건축 - 건축물 - 단독주택(연면적 : 284.06㎡, 지상 4층, 지하 1층)   떨어짐(5미터 이상 ~ 10미터 미만)
#
#   물적사고     작업프로세스                                               사고경위  \
# 1   없음  상차 및 하역작업  철골자재(데크플레이트(슈퍼데크))를 화물차에서 지게차로 하차 적재위치에 내려놓는 중...
# 2   없음         기타  2022년04월27일 오전07시20분경 보라동 근린생활시설 및 다세대주택 신축공사 ...
# 3   없음       설치작업  2022.04.22 금요일 09시 10분경 202동 10호 다용도실에서 전기작업을 ...
# 4   없음         기타  일용근로자인 김**씨는 2022년 04월 20일 (수요일) 오전 06시57 분경에 ...
# 5   없음       해체작업  외부 비계해체작업 준비 중 작업자(비계공)가 3층 계단창을 통해 비계 및 작업발판으...
#
#                  사고원인                                           구체적 사고원인  \
# 1                 부주의             받침대 설치 시 측면에서 설치를 해야하나 지게차 앞에서 받침대를 설치
# 2                  기타  신축공사 현장 내 대기실에서 작업 착수 전 동료들과 모여 대기중 송**이 갑자기 쓰...
# 3                  기타                               현장 정리정돈 미흡 및 근로자 부주의
# 4                  기타                                 개인 질병(심근경색)에 따른 사고
# 5  복장, 개인보호구의 부적절한 사용  안전고리 체결 후 작업준비가 이루어져야 했으나 안전고리 미체결 등으로 사고가 발생한...
#
#    사망자수  부상자수 공종대분류 공종소분류 객체대분류   객체소분류    시설장소  \
# 1     1     0    건축  철골공사  건설자재  데크플레이트  근린생활시설
# 2     1     0    기타    기타    질병      질병    공동주택
# 3     1     0    건축  가설공사   가시설     거푸집      기타
# 4     1     0    기타    기타    질병      질병    부지조성
# 5     1     0    건축  가설공사   가시설    작업발판    단독주택
#
#                             위치장소                           부위위치
# 1                             외부                             하역
# 2  작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망  작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망
# 3                             내부                          상부(위)
# 4                             내부                          상부(위)
# 5                             외벽                             고소

# %% [markdown]
# # **1. 사고원인**
# ---

# %% [markdown]
# ## **1.1 사고원인 고유값 확인**

# %%
case['사고원인'].unique()
# Out:
# array(['부주의', '기타', '복장, 개인보호구의 부적절한 사용', '작업자의 단순과실',
#        '타설 미흡(하중, 속도, 순서 등)', '작업중 충돌', '작업중 이동', '중량물 운반', '작업순서 미흡',
#        '무모한 또는 불필요한 행위 및 동작', '전도 예방조치 미흡', '설치 미흡', '작업발판 고정 철선 절단',
#        '구조물등 그밖의 위험방치 및 미확인', '자재불량에 의한 파손', '설비,기계등의 부적절한 사용 관리',
#        '고소작업대 설치 미흡', '불안전한 작업자세', '주용도외 사용', '지지부재 이탈', '가설공사 전담기술자 미배치',
#        '지반상태 불량', '버팀대 설치 미흡', '돌풍', '중량물 취급 미흡', '거푸집 조기 해체',
#        '부재의 체결강도 미흡', '거푸집 긴결재/앵커 위치', '작업신호 불량', '작업 공간 협소',
#        '절단방향 판단 오류', '로프 매듭풀림', '집중호우', '방호시설 미설치', '장비운용 미흡', '지지대 미설치',
#        '철근 과적재', '조립불량', '가새 설치 미흡', '와이어로프 이탈', '자중에 의한 처짐', '이동식 비계 조정',
#        '적재방법 불량', '거푸집 긴결재/앵커 해체', '장애물 충돌', '지지구조물 설치 미흡', '용접부 탈락',
#        '연결부 파손', '지지대 연결부 파손', '작업자 하중', '과다한 굴착', '브레이크 파열', '파손', '토사층',
#        '탈락', '소음진동', '부석 미제거', '지장물 조치 미흡', '해체방법 부적정', '흙막이 가시설 설치미흡',
#        '조작 미숙', '유도자 미배치', '토압', '궤도차량 충돌', '버팀대 미설치', '토사유실', '시공순서 불량',
#        '크레인줄걸이', '크레인와이어', '철근배근 미흡', '단차발생', '사면활동', '철거 잔재물 적치',
#        '추진방향 판단 미흡', '부석제거 미흡', '철근 전도방지 미조치',
#        '작업전 부석, 균열, 함수 등 변화 점검 미흡', '기계적 결함', '굴착면 기울기', '용접불량', '긴결 미흡',
#        '상재하중', '용접부위 파단', '집중하중', '버팀목 미설치', '경사각 미준수', '수평보강 및 지지 미흡',
#        '로프 강도 불충분', '굴착공법 및 순서 불량', '과하중', '버팀목 설치 미흡', '풍화암층 파쇄대',
#        '콘크리트 유동화', '인양로프 해체방법 미흡', '시공계획서 및 시공상세도 미준수', '설치방법 불량',
#        '거푸집 하단 미고정', '시공계획서 미작성', '부적정한 이음방법', '외력', '지하수 유입',
#        '거푸집 수직도 미확보', '지지부재 파단', '인양방법 불량', '구조조립상태 불량', '전단변형 미고려',
#        '지지용 로프 풀림', '구조안전성 미검토', '수직도 미확보', '결속벤딩 해체', '볼트 결함', '철근결속 미흡',
#        '분할 시공', '와이어로프 파단', '지반 함수량 증가', '배관 탈락', '하중의 지지상태 미흡',
#        '벽이음 일부해체', '부착토 미제거', '지반붕괴', '과도한 변형', '과적운행', '침하', '충격하중',
#        '강도 발휘전 해체', '절취면 기울기', '과속주행', '적재하중', '강성 부족', '시공하중', '작업하중',
#        '유압잭 결함', '설계시 작업하중과 장비하중의 실중량 미고려', '인화성 유증기 잔류', '단층파쇄대',
#        '붐 연결핀 파단', '재사용', '임의 설계변경', '풍화암층', '동절기 콘크리트 타설', '가새 미설치',
#        '설치작업순서 미준수', '아웃트리거 설치 미흡', '동결융해', '거푸집의 수직도 및 레벨', '히빙',
#        '중량물 설치방법 미흡', '구조기준 미준수', '작업원 교육 미실시', '해체계획 미수립', '철골빔 앵커 이탈',
#        '이동식작업차 각 부재의 변형', '전석제거 미흡', '편하중', '연결볼트 해체', '수직재 연결핀 미설치',
#        '철골보 접합부 불량', '전용 달기구 미사용',
#        '설치 미흡, 이동식 비계 조정, 구조물등 그밖의 위험방치 및 미확인', '무모한 또는 불필요한 행위 및 동작, 기타',
#        '작업자의 단순과실, 무모한 또는 불필요한 행위 및 동작, 불안전한 작업자세', '작업중 이동, 작업자의 단순과실',
#        '조작 미숙, 작업자의 단순과실', '작업중 이동, 설비,기계등의 부적절한 사용 관리',
#        '불안전한 작업자세, 작업자의 단순과실, 기타',
#        '무모한 또는 불필요한 행위 및 동작, 설비,기계등의 부적절한 사용 관리',
#        '작업자의 단순과실, 불안전한 작업자세, 고소작업대 설치 미흡', '부주의, 작업순서 미흡',
#        '조립도 작성시 좌굴 미고려', '불안전한 작업자세, 작업자의 단순과실', '부주의, 설치방법 불량',
#        '작업순서 미흡, 작업자의 단순과실', '자재불량에 의한 파손, 파손, 복장, 개인보호구의 부적절한 사용',
#        '창호 위치 조정 미숙', '고소작업대 설치 미흡, 부주의', '중량물 운반, 작업자의 단순과실',
#        '무모한 또는 불필요한 행위 및 동작, 작업순서 미흡', '작업자의 단순과실, 외력, 기타',
#        '부주의, 작업중 이동, 작업자의 단순과실', '작업자의 단순과실, 복장, 개인보호구의 부적절한 사용',
#        '갑작스런 붐 강하', '무모한 또는 불필요한 행위 및 동작, 복장, 개인보호구의 부적절한 사용, 작업자의 단순과실',
#        '장비운용 미흡, 작업중 충돌', '작업자의 단순과실, 불안전한 작업자세, 작업중 이동', '암반층 파쇄대',
#        '해체작업 방법 불량', '타설순서 미준수', '작업자의 단순과실, 장비운용 미흡',
#        '구조물등 그밖의 위험방치 및 미확인, 작업자의 단순과실', '불안전한 작업자세, 작업중 이동',
#        '부주의, 작업 공간 협소 , 작업중 이동', '중량물 하중집중', '부주의, 작업자의 단순과실',
#        '거푸집 긴결재/앵커 해체, 연결볼트 해체', '작업중 충돌, 작업자의 단순과실',
#        '작업자의 단순과실, 설비,기계등의 부적절한 사용 관리', '해체방법 부적정, 작업자의 단순과실',
#        '설치방법 불량, 작업자의 단순과실', '불안전한 작업자세, 설비,기계등의 부적절한 사용 관리',
#        '지지부재 이탈, 지지구조물 설치 미흡', '작업자의 단순과실, 작업중 이동',
#        '부주의, 작업순서 미흡, 구조물등 그밖의 위험방치 및 미확인, 불안전한 작업자세, 작업자의 단순과실',
#        '작업신호 불량, 복장, 개인보호구의 부적절한 사용', '철골빔 앵커볼트 빠짐',
#        '작업자의 단순과실, 불안전한 작업자세', '작업중 이동, 작업 공간 협소',
#        '무모한 또는 불필요한 행위 및 동작, 작업자의 단순과실',
#        '구조물등 그밖의 위험방치 및 미확인, 설비,기계등의 부적절한 사용 관리, 불안전한 작업자세, 작업자의 단순과실, 무모한 또는 불필요한 행위 및 동작',
#        '구조물등 그밖의 위험방치 및 미확인, 설비,기계등의 부적절한 사용 관리, 불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작, 작업자의 단순과실',
#        '무모한 또는 불필요한 행위 및 동작, 불안전한 작업자세, 설비,기계등의 부적절한 사용 관리',
#        '브레이크 파열, 파손', '지반침하', '작업순서 미흡, 복장, 개인보호구의 부적절한 사용',
#        '중량물 운반, 부주의', '버팀대 설치 미흡, 불안전한 작업자세, 중량물 운반, 중량물 하중집중',
#        '해체작업 방법 불량, 해체작업 순서 불량', '작업자의 단순과실, 기타', '부등침하', '부주의, 기타',
#        '조립불량, 무모한 또는 불필요한 행위 및 동작, 복장, 개인보호구의 부적절한 사용, 작업자의 단순과실',
#        '불안전한 작업자세, 복장, 개인보호구의 부적절한 사용', '장비운용 미흡, 불안전한 작업자세, 작업자의 단순과실',
#        '토사반출 방법 불량', '불안전한 작업자세, 작업자의 단순과실, 적재방법 불량', '부적절한 흙막이 설치',
#        '적재방법 불량, 불안전한 작업자세', '불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작',
#        '철근자중 및 이상응력', '인양로프 해체방법 미흡, 작업신호 불량', '연결부 파손 , 지지용 앵커 탈락',
#        '작업중 충돌, 불안전한 작업자세', '작업자의 단순과실, 부주의',
#        '부주의, 작업자의 단순과실, 구조물등 그밖의 위험방치 및 미확인', '작업신호 불량, 인양방법 불량',
#        '작업자의 단순과실, 무모한 또는 불필요한 행위 및 동작, 수직도 미확보',
#        '복장, 개인보호구의 부적절한 사용, 부주의', '작업자의 단순과실, 구조물등 그밖의 위험방치 및 미확인',
#        '앵커볼트 파손', '해체작업 순서 불량', '설비,기계등의 부적절한 사용 관리, 기계적 결함',
#        '버팀대 설치 미흡, 작업자 하중, 작업자의 단순과실', '불연속면 미립자 유실 및 이완하중 증가',
#        '중량물 운반, 작업순서 미흡, 중량물 하중집중, 불안전한 작업자세',
#        '작업자의 단순과실, 무모한 또는 불필요한 행위 및 동작',
#        '로프 매듭풀림, 구조물등 그밖의 위험방치 및 미확인, 복장, 개인보호구의 부적절한 사용',
#        '작업자의 단순과실, 해체작업 순서 불량', '작업원 교육 미실시, 구조물등 그밖의 위험방치 및 미확인',
#        '설치 미흡, 복장, 개인보호구의 부적절한 사용, 부주의',
#        '불안전한 작업자세, 설비,기계등의 부적절한 사용 관리, 작업자의 단순과실', '고소작업대 설치 미흡, 지지부재 이탈',
#        '부주의, 불안전한 작업자세', '작업자의 단순과실, 작업 공간 협소 , 작업중 이동, 작업중 충돌',
#        '복장, 개인보호구의 부적절한 사용, 작업중 이동', '흙막이가시설 설치시기', '불안전한 작업자세, 작업 공간 협소',
#        '설비,기계등의 부적절한 사용 관리, 불안전한 작업자세', '불안전한 작업자세, 조작 미숙',
#        '작업자의 단순과실, 작업신호 불량', '해체작업 방법 불량, 작업자의 단순과실', '불안전한 작업자세, 작업중 충돌',
#        '부주의, 지지구조물 설치 미흡', '작업 공간 협소 , 구조물등 그밖의 위험방치 및 미확인, 작업자의 단순과실',
#        '구조 및 주변상황', '작업중 이동, 작업순서 미흡', '이동식 비계 조정, 작업하중', '1차 숏크리트면의 이물질',
#        '해체상태 방치, 해체계획 미수립', '작업중 이동, 장애물 충돌, 불안전한 작업자세',
#        '구조물등 그밖의 위험방치 및 미확인, 불안전한 작업자세', '조립불량, 작업순서 미흡, 작업자의 단순과실',
#        '작업중 충돌, 중량물 하중집중', '작업 공간 협소 , 장비운용 미흡',
#        '중량물 하중집중, 불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작, 작업자의 단순과실',
#        '강성 부족, 철근 전도방지 미조치, 불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작',
#        '부주의, 작업 공간 협소 , 작업신호 불량, 장비운용 미흡', '탈락, 작업중 이동', '돌풍, 지지대 미설치',
#        '긴결 미흡, 부재의 체결강도 미흡', '기타, 작업자의 단순과실', '작업 공간 협소 , 기타',
#        '과하중, 암반층 파쇄대', '복장, 개인보호구의 부적절한 사용, 작업자의 단순과실',
#        '전도 예방조치 미흡, 작업자의 단순과실', '불안전한 작업자세, 부주의', '작업자의 단순과실, 인양방법 불량',
#        '무모한 또는 불필요한 행위 및 동작, 불안전한 작업자세, 작업자의 단순과실',
#        '작업중 이동, 구조물등 그밖의 위험방치 및 미확인, 작업 공간 협소 , 장애물 충돌',
#        '작업 공간 협소 , 불안전한 작업자세, 작업자의 단순과실',
#        '작업자의 단순과실, 구조물등 그밖의 위험방치 및 미확인, 고소작업대 설치 미흡', '흙막이 가시설 미설치',
#        '불안전한 작업자세, 배관 탈락', '작업자의 단순과실, 자중', '구조물등 그밖의 위험방치 및 미확인, 부주의',
#        '작업중 이동, 구조물등 그밖의 위험방치 및 미확인', '작업자의 단순과실, 조작 미숙',
#        '기타, 불안전한 작업자세, 복장, 개인보호구의 부적절한 사용',
#        '작업순서 미흡, 작업 공간 협소 , 불안전한 작업자세', '우수유입', '작업중 이동, 장비운용 미흡',
#        '해체상태 방치', '작업순서 미흡, 불안전한 작업자세, 작업자의 단순과실', '자재불량에 의한 파손, 파손',
#        '작업순서 미흡, 부주의', '작업중 이동, 무모한 또는 불필요한 행위 및 동작',
#        '불안전한 작업자세, 추진방향 판단 미흡',
#        '복장, 개인보호구의 부적절한 사용, 작업자의 단순과실, 구조물등 그밖의 위험방치 및 미확인',
#        '동바리 조립도 미작성', '작업 공간 협소 , 작업자의 단순과실', '작업자의 단순과실, 앵커강도 미흡',
#        '파손, 조작 미숙', '부주의, 복장, 개인보호구의 부적절한 사용', '작업신호 불량, 작업중 충돌',
#        '작업신호 불량, 조작 미숙, 작업자의 단순과실', '작업신호 불량, 무모한 또는 불필요한 행위 및 동작',
#        '해체작업 방법 불량, 작업신호 불량', '불안전한 작업자세, 복장, 개인보호구의 부적절한 사용, 작업신호 불량',
#        '작업중 이동, 불안전한 작업자세, 작업자의 단순과실', '중량물 하중집중, 불안전한 작업자세, 작업자의 단순과실',
#        '장비운용 미흡, 불안전한 작업자세', '구조물등 그밖의 위험방치 및 미확인, 작업중 이동',
#        '중량물 운반, 적재하중', '작업자의 단순과실, 작업 공간 협소 , 중량물 하중집중',
#        '불안전한 작업자세, 작업자의 단순과실, 작업중 이동',
#        '작업중 이동, 불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작, 복장, 개인보호구의 부적절한 사용',
#        '장비운용 미흡, 작업신호 불량', '작업신호 불량, 작업자의 단순과실',
#        '볼트 결함, 구조물등 그밖의 위험방치 및 미확인', '인양방법 불량, 장애물 충돌',
#        '무모한 또는 불필요한 행위 및 동작, 중량물 하중집중, 불안전한 작업자세',
#        '작업자의 단순과실, 무모한 또는 불필요한 행위 및 동작, 불안전한 작업자세, 기타',
#        '조작 미숙, 불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작',
#        '설비,기계등의 부적절한 사용 관리, 작업자의 단순과실, 작업신호 불량',
#        '무모한 또는 불필요한 행위 및 동작, 작업중 이동',
#        '작업자의 단순과실, 무모한 또는 불필요한 행위 및 동작, 복장, 개인보호구의 부적절한 사용',
#        '부주의, 작업중 이동', '불안전한 작업자세, 작업자의 단순과실, 가설공사 전담기술자 미배치',
#        '작업중 이동, 철근결속 미흡, 작업자의 단순과실', '전도 예방조치 미흡, 불안전한 작업자세',
#        '흙막이 지보공 조립 미흡', '조작 미숙, 작업자의 단순과실, 무모한 또는 불필요한 행위 및 동작',
#        '무모한 또는 불필요한 행위 및 동작, 불안전한 작업자세',
#        '불안전한 작업자세, 복장, 개인보호구의 부적절한 사용, 연결볼트 해체',
#        '작업자의 단순과실, 불안전한 작업자세, 설비,기계등의 부적절한 사용 관리',
#        '작업자의 단순과실, 가설공사 전담기술자 미배치', '구조 및 주변상황, 돌풍',
#        '복장, 개인보호구의 부적절한 사용, 적재방법 불량',
#        '작업자의 단순과실, 불안전한 작업자세, 복장, 개인보호구의 부적절한 사용', '인양방법 불량, 적재방법 불량',
#        '중량물 하중집중, 무모한 또는 불필요한 행위 및 동작, 작업자의 단순과실', '중량물 하중집중, 작업자의 단순과실',
#        '거푸집 하단 미고정, 작업발판 고정 철선 절단',
#        '작업자의 단순과실, 복장, 개인보호구의 부적절한 사용, 무모한 또는 불필요한 행위 및 동작',
#        '불안전한 작업자세, 구조물등 그밖의 위험방치 및 미확인', '부주의, 적재방법 불량', '타설속도 미준수',
#        '해체작업 방법 불량, 해체작업 순서 불량, 작업자의 단순과실, 불안전한 작업자세',
#        '구조 및 주변상황, 구조물등 그밖의 위험방치 및 미확인',
#        '부주의, 구조물등 그밖의 위험방치 및 미확인, 작업자의 단순과실', '작업자의 단순과실, 적재방법 불량',
#        '무모한 또는 불필요한 행위 및 동작, 작업자의 단순과실, 작업신호 불량', '돌풍, 기타',
#        '우수유입, 작업자의 단순과실', '무모한 또는 불필요한 행위 및 동작, 장비운용 미흡',
#        '복장, 개인보호구의 부적절한 사용, 자재불량에 의한 파손', '작업신호 불량, 구조물등 그밖의 위험방치 및 미확인',
#        '구조물등 그밖의 위험방치 및 미확인, 기타', '지지용 앵커 탈락', '작업자의 단순과실, 크레인줄걸이',
#        '보강재 미설치', '과하중, 긴결 미흡, 지지대 미설치', '작업자의 단순과실, 추진방향 판단 미흡',
#        '작업신호 불량, 작업 공간 협소', '인양 및 선회 작업순서 불량', '작업중 이동, 지지대 미설치',
#        '부주의, 작업중 이동, 불안전한 작업자세, 작업자의 단순과실', '작업신호 불량, 작업 공간 협소 , 중량물 운반',
#        '작업신호 불량, 설치방법 불량, 불안전한 작업자세', '절단방향 판단 오류, 불안전한 작업자세',
#        '불안전한 작업자세, 작업 공간 협소 , 중량물 운반', '장애물 충돌, 작업자의 단순과실',
#        '작업 공간 협소 , 작업중 이동',
#        '구조물등 그밖의 위험방치 및 미확인, 복장, 개인보호구의 부적절한 사용, 부주의',
#        '지지구조물 설치 미흡, 구조물등 그밖의 위험방치 및 미확인', '부주의, 무모한 또는 불필요한 행위 및 동작, 기타',
#        '구조 및 주변상황, 부주의',
#        '불안전한 작업자세, 구조물등 그밖의 위험방치 및 미확인, 복장, 개인보호구의 부적절한 사용',
#        '불안전한 작업자세, 작업중 이동, 설치방법 불량', '방호시설 미설치, 부주의, 작업자의 단순과실',
#        '굴착면 기울기, 작업중 이동', '해체작업 방법 불량, 버팀대 설치 미흡', '이동식 비계 조정, 작업자의 단순과실',
#        '락볼트 정착방법', '작업순서 미흡, 작업중 이동', '철거 잔재물 적치, 구조물등 그밖의 위험방치 및 미확인',
#        '연약대 및 절리', '작업중 이동, 전도 예방조치 미흡', '설치작업순서 미준수, 작업자의 단순과실',
#        '작업중 충돌, 구조물등 그밖의 위험방치 및 미확인',
#        '무모한 또는 불필요한 행위 및 동작, 구조물등 그밖의 위험방치 및 미확인',
#        '작업자의 단순과실, 지지대 미설치, 작업중 이동, 작업자 하중',
#        '해체작업 방법 불량, 해체작업 순서 불량, 구조물등 그밖의 위험방치 및 미확인, 불안전한 작업자세, 설비,기계등의 부적절한 사용 관리',
#        '구조물등 그밖의 위험방치 및 미확인, 불안전한 작업자세, 작업자의 단순과실',
#        '불안전한 작업자세, 작업자의 단순과실, 복장, 개인보호구의 부적절한 사용',
#        '작업중 이동, 구조물등 그밖의 위험방치 및 미확인, 작업자의 단순과실',
#        '복장, 개인보호구의 부적절한 사용, 작업자의 단순과실, 지지구조물 설치 미흡',
#        '작업자의 단순과실, 작업 공간 협소', '고소작업대 설치 미흡, 불안전한 작업자세', '지보조치 미흡',
#        '불안전한 작업자세, 작업중 이동, 작업자의 단순과실',
#        '작업순서 미흡, 조작 미숙, 불안전한 작업자세, 작업자의 단순과실', '설치방법 불량, 설치작업순서 미준수',
#        '중량물 하중집중, 중량물 운반', '구조물등 그밖의 위험방치 및 미확인, 무모한 또는 불필요한 행위 및 동작',
#        '공기역학적 하중', '작업신호 불량, 장비운용 미흡', '기타, 부주의', '연결부 파손 , 부주의',
#        '인양로프 해체방법 미흡, 적재방법 불량', '작업중 이동, 작업자의 단순과실, 불안전한 작업자세',
#        '중량물 운반, 작업 공간 협소', '중량물 운반, 무모한 또는 불필요한 행위 및 동작', '지지대 미설치, 탈락',
#        '작업 공간 협소 , 작업중 이동, 작업자의 단순과실',
#        '불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작, 작업자의 단순과실, 기타',
#        '불안전한 작업자세, 지반상태 불량', '거푸집 하단 미고정, 작업자 하중',
#        '중량물 하중집중, 설비,기계등의 부적절한 사용 관리', '조작 미숙, 부주의',
#        '무모한 또는 불필요한 행위 및 동작, 작업신호 불량', '복장, 개인보호구의 부적절한 사용, 불안전한 작업자세',
#        '작업하중, 중량물 운반', '조작 미숙, 무모한 또는 불필요한 행위 및 동작',
#        '복장, 개인보호구의 부적절한 사용, 작업자의 단순과실, 설비,기계등의 부적절한 사용 관리',
#        '해체작업 방법 불량, 인양방법 불량', '중량물 운반, 작업신호 불량',
#        '작업자의 단순과실, 무모한 또는 불필요한 행위 및 동작, 작업 공간 협소 , 작업순서 미흡',
#        '인양로프 해체방법 미흡, 인양방법 불량', '작업중 이동, 부주의',
#        '부주의, 결속벤딩 해체, 불안전한 작업자세, 복장, 개인보호구의 부적절한 사용, 작업자의 단순과실',
#        '설치 미흡, 설치방법 불량, 작업중 충돌', '기타, 결속벤딩 해체', '기계적 결함, 장비운용 미흡',
#        '작업신호 불량, 무모한 또는 불필요한 행위 및 동작, 불안전한 작업자세', '임시 받침목 제거',
#        '불안전한 작업자세, 중량물 운반',
#        '용접부위 파단, 목표 용접강도 미확보, 용접불량, 작업원 교육 미실시, 불안전한 작업자세, 복장, 개인보호구의 부적절한 사용',
#        '고소작업대 설치 미흡, 해체작업 방법 불량, 복장, 개인보호구의 부적절한 사용', '작업 공간 협소 , 토사층',
#        '불안전한 작업자세, 설치작업순서 미준수', '자중, 작업 공간 협소 , 작업자의 단순과실, 불안전한 작업자세',
#        '조립불량, 지지구조물 설치 미흡, 작업자의 단순과실', '작업순서 미흡, 작업신호 불량, 작업자의 단순과실',
#        '집중타설', '파손, 작업자 하중, 작업중 이동', '부주의, 해체작업 방법 불량',
#        '작업 공간 협소 , 불안전한 작업자세', '작업중 충돌, 장애물 충돌',
#        '장애물 충돌, 해체상태 방치, 작업자의 단순과실', '작업원 교육 미실시, 작업신호 불량',
#        '설비,기계등의 부적절한 사용 관리, 무모한 또는 불필요한 행위 및 동작, 복장, 개인보호구의 부적절한 사용',
#        '장비운용 미흡, 조작 미숙, 작업자의 단순과실', '기계적 결함, 장비운용 미흡, 작업자의 단순과실',
#        '과하중, 중량물 운반',
#        '부주의, 장비운용 미흡, 장애물 충돌, 구조물등 그밖의 위험방치 및 미확인, 조작 미숙, 작업자의 단순과실',
#        '부주의, 작업신호 불량, 작업자의 단순과실', '작업자의 단순과실, 버팀목 설치 미흡',
#        '설치방법 불량, 설비,기계등의 부적절한 사용 관리, 작업자의 단순과실',
#        '중량물 운반, 부주의, 무모한 또는 불필요한 행위 및 동작', '설계도서 임의변경 시공',
#        '고소작업대 설치 미흡, 복장, 개인보호구의 부적절한 사용', '해체작업 순서 불량, 작업신호 불량',
#        '자재불량에 의한 파손, 복장, 개인보호구의 부적절한 사용', '작업중 이동, 장애물 충돌, 작업자의 단순과실',
#        '작업중 충돌, 기타', '설치방법 불량, 인양로프 해체방법 미흡, 작업신호 불량',
#        '지지대 미설치, 복장, 개인보호구의 부적절한 사용, 구조물등 그밖의 위험방치 및 미확인',
#        '해체작업 방법 불량, 해체작업 순서 불량, 불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작',
#        '지지구조물 설치 미흡, 불안전한 작업자세, 작업자의 단순과실', '거푸집 긴결재/앵커 해체, 해체작업 방법 불량',
#        '적재방법 불량, 무모한 또는 불필요한 행위 및 동작', '조작 미숙, 작업중 충돌, 장비운용 미흡',
#        '수직철근 분절시공 미실시, 수직철도 전도', '작업하중, 해체작업 방법 불량, 작업자의 단순과실',
#        '기계적 결함, 구조물등 그밖의 위험방치 및 미확인',
#        '설비,기계등의 부적절한 사용 관리, 무모한 또는 불필요한 행위 및 동작, 작업자의 단순과실', '부주의, 부주의',
#        '불안전한 작업자세, 이동식 비계 조정', '유도자 미배치, 구조물등 그밖의 위험방치 및 미확인', nan,
#        '중량물 운반, 중량물 하중집중', '적재방법 불량, 중량물 하중집중, 작업자의 단순과실',
#        '중량물 하중집중, 인양방법 불량, 작업중 충돌', '작업순서 미흡, 작업자의 단순과실, 불안전한 작업자세',
#        '긴결 미흡, 작업중 이동, 충격하중', '긴결 미흡, 작업전 부석, 균열, 함수 등 변화 점검 미흡',
#        '작업 공간 협소 , 조작 미숙', '고소작업대 설치 미흡, 복장, 개인보호구의 부적절한 사용, 불안전한 작업자세',
#        '중량물 하중집중, 지반상태 불량', '무모한 또는 불필요한 행위 및 동작, 작업순서 미흡, 작업중 충돌', '자중',
#        '해체작업 순서 불량, 불안전한 작업자세', '철거 잔재물 적치, 작업중 이동',
#        '해체작업 순서 불량, 해체작업 방법 불량', '조작 미숙, 작업신호 불량',
#        '작업중 이동, 전도 예방조치 미흡, 불안전한 작업자세, 무모한 또는 불필요한 행위 및 동작',
#        '낙뢰, 풍화암층 파쇄대', '불안전한 작업자세, 작업자의 단순과실, 작업순서 미흡, 장비운용 미흡',
#        '작업중 이동, 불안전한 작업자세', '파이핑', '장비운용 미흡, 작업자의 단순과실',
#        '작업 공간 협소 , 구조물등 그밖의 위험방치 및 미확인',
#        '불안전한 작업자세, 복장, 개인보호구의 부적절한 사용, 작업자의 단순과실, 작업중 이동',
#        '거푸집 긴결재/앵커 해체, 불안전한 작업자세', '장비운용 미흡, 설비,기계등의 부적절한 사용 관리',
#        '기타, 부주의, 불안전한 작업자세, 작업자의 단순과실', '작업자의 단순과실, 부주의, 기타', '과도한 토압',
#        '부주의, 작업 공간 협소 , 작업순서 미흡, 불안전한 작업자세',
#        '설비,기계등의 부적절한 사용 관리, 작업자의 단순과실', '수직철근 분절시공 미실시', '조작 미숙, 장비운용 미흡',
#        '작업자의 단순과실, 유도자 미배치', '작업중 이동, 자중, 부주의, 무모한 또는 불필요한 행위 및 동작'],
#       dtype=object)

# %%
reason_array = case['사고원인'].unique()
reason = pd.DataFrame(data = reason_array, columns = ['사고원인'])
reason.head()
# Out:
#                   사고원인
# 0                  부주의
# 1                   기타
# 2   복장, 개인보호구의 부적절한 사용
# 3            작업자의 단순과실
# 4  타설 미흡(하중, 속도, 순서 등)

# %%
# 사고원인 고유값 파일
reason.to_csv('2_1. 사고원인.csv')

# %% [markdown]
# ## **1.2 사고원인 분류**

# %% [markdown]
# - na = False → NaN이 존재하는 경우에는 na로 NaN 결과를 치환해 주도록 설정
# - 참고 : https://ponyozzang.tistory.com/622
# - 여러 조건으로 새로운 열 만들기 : https://www.delftstack.com/ko/howto/python-pandas/how-to-create-dataframe-column-based-on-given-condition-in-pandas/

# %%
import numpy as np

conditions = [
    (case['사고원인'].str.contains('집중호우|돌풍|낙뢰', na=False)),
    (case['사고원인'].str.contains('부주의|단순과실|미|불필요한|부적절한|불안전한|불량', na=False)),
    (case['사고원인'].str.contains('기타', na=False))
]

c_list = ['날씨', '사람', '기타']

case['사고원인분류'] = np.select(conditions, c_list, default = '사고')

case.head()
# Out:
#                                            사고명                     기상상태  \
# 1                           외남동162 근린생활시설 신축공사  날씨 : 맑음기온 : 23℃습도 : 20%
# 2  보라동 391-23 근린생활시설 및 다세대주택 신축공사 작업 착수 전 사망사고  날씨 : 흐림기온 : 22℃습도 : 50%
# 3                        송산그린시티 EB4블록 형틀공 추락사고  날씨 : 흐림기온 : 15℃습도 : 74%
# 4                             화성비봉 공공주택지구 조성공사  날씨 : 맑음기온 : 15℃습도 : 51%
# 5                         상도동 243-19 신축공사 추락사고  날씨 : 흐림기온 : 19℃습도 : 25%
#
#                                             시설물 종류                   인적사고  \
# 1  건축 - 건축물 - 근린생활시설(연면적 : 455.46㎡, 지상 2층, 지하 0층)                  물체에 맞음
# 2    건축 - 건축물 - 공동주택(연면적 : 709.85㎡, 지상 5층, 지하 0층)                      질병
# 3   건축 - 건축물 - 기타(연면적 : 24,161.30㎡, 지상 3층, 지하 1층)                      찔림
# 4                                   토목 - 기타 - 부지조성                     질병
# 5    건축 - 건축물 - 단독주택(연면적 : 284.06㎡, 지상 4층, 지하 1층)   떨어짐(5미터 이상 ~ 10미터 미만)
#
#   물적사고     작업프로세스                                               사고경위  \
# 1   없음  상차 및 하역작업  철골자재(데크플레이트(슈퍼데크))를 화물차에서 지게차로 하차 적재위치에 내려놓는 중...
# 2   없음         기타  2022년04월27일 오전07시20분경 보라동 근린생활시설 및 다세대주택 신축공사 ...
# 3   없음       설치작업  2022.04.22 금요일 09시 10분경 202동 10호 다용도실에서 전기작업을 ...
# 4   없음         기타  일용근로자인 김**씨는 2022년 04월 20일 (수요일) 오전 06시57 분경에 ...
# 5   없음       해체작업  외부 비계해체작업 준비 중 작업자(비계공)가 3층 계단창을 통해 비계 및 작업발판으...
#
#                  사고원인                                           구체적 사고원인  \
# 1                 부주의             받침대 설치 시 측면에서 설치를 해야하나 지게차 앞에서 받침대를 설치
# 2                  기타  신축공사 현장 내 대기실에서 작업 착수 전 동료들과 모여 대기중 송**이 갑자기 쓰...
# 3                  기타                               현장 정리정돈 미흡 및 근로자 부주의
# 4                  기타                                 개인 질병(심근경색)에 따른 사고
# 5  복장, 개인보호구의 부적절한 사용  안전고리 체결 후 작업준비가 이루어져야 했으나 안전고리 미체결 등으로 사고가 발생한...
#
#    사망자수  부상자수 공종대분류 공종소분류 객체대분류   객체소분류    시설장소  \
# 1     1     0    건축  철골공사  건설자재  데크플레이트  근린생활시설
# 2     1     0    기타    기타    질병      질병    공동주택
# 3     1     0    건축  가설공사   가시설     거푸집      기타
# 4     1     0    기타    기타    질병      질병    부지조성
# 5     1     0    건축  가설공사   가시설    작업발판    단독주택
#
#                             위치장소                           부위위치 사고원인분류
# 1                             외부                             하역     사람
# 2  작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망  작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망     기타
# 3                             내부                          상부(위)     기타
# 4                             내부                          상부(위)     기타
# 5                             외벽                             고소     사람

# %%
# 사고원인 분류 컬럼(사람, 사고, 날씨,...) 추가 파일
case.to_csv('2_2. 사고원인 분류.csv')

# %% [markdown]
# # **1.3 사고원인 시각화**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
# case.columns = ['name', 'weather', 'facility_kind', 'human_accident', 'material_accident', 'work', 'accident_sequence', 'reason', 'detail_reason', 'death', 'injury', 'type1', 'type2', 'object_class1', 'object_class2', 'place', 'location', 'detail_location', 'reason_class']

# %% [markdown]
# ### **1.3.1 사고원인의 대분류**

# %%
f, ax = plt.subplots(1, 2, figsize = (15,5))

case['사고원인분류'].value_counts().plot.pie(autopct = '%1.1f%%', ax = ax[0], shadow = True)
ax[0].set_title('pie plot')
ax[0].set_ylabel('')

sns.countplot('사고원인분류', data = case, ax = ax[1])
ax[1].set_title('count plot')

plt.show()
# Out:
# c:\Users\seonghunyun\anaconda3\envs\safey_helmet\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### **2.3.2 사고원인 중 사람 관련 데이터**

# %%
conditions = [
    (case['사고원인'].str.contains('부주의', na=False)),
    (case['사고원인'].str.contains('단순과실', na=False)),
    (case['사고원인'].str.contains('미', na=False)),
    (case['사고원인'].str.contains('불필요', na=False)),
    (case['사고원인'].str.contains('부적절', na=False)),
    (case['사고원인'].str.contains('불안전', na=False)),
    (case['사고원인'].str.contains('불량', na=False)),
    (case['사고원인'].str.contains('기타', na=False))
]

c_list = ['부주의', '단순과실', '진행하지않음', '불필요', '부적절', '불안전', '불량', '기타']

case['사고원인분류2'] = np.select(conditions, c_list, default = '사고, 날씨')

case.head()
# Out:
#                                            사고명                     기상상태  \
# 1                           외남동162 근린생활시설 신축공사  날씨 : 맑음기온 : 23℃습도 : 20%
# 2  보라동 391-23 근린생활시설 및 다세대주택 신축공사 작업 착수 전 사망사고  날씨 : 흐림기온 : 22℃습도 : 50%
# 3                        송산그린시티 EB4블록 형틀공 추락사고  날씨 : 흐림기온 : 15℃습도 : 74%
# 4                             화성비봉 공공주택지구 조성공사  날씨 : 맑음기온 : 15℃습도 : 51%
# 5                         상도동 243-19 신축공사 추락사고  날씨 : 흐림기온 : 19℃습도 : 25%
#
#                                             시설물 종류                   인적사고  \
# 1  건축 - 건축물 - 근린생활시설(연면적 : 455.46㎡, 지상 2층, 지하 0층)                  물체에 맞음
# 2    건축 - 건축물 - 공동주택(연면적 : 709.85㎡, 지상 5층, 지하 0층)                      질병
# 3   건축 - 건축물 - 기타(연면적 : 24,161.30㎡, 지상 3층, 지하 1층)                      찔림
# 4                                   토목 - 기타 - 부지조성                     질병
# 5    건축 - 건축물 - 단독주택(연면적 : 284.06㎡, 지상 4층, 지하 1층)   떨어짐(5미터 이상 ~ 10미터 미만)
#
#   물적사고     작업프로세스                                               사고경위  \
# 1   없음  상차 및 하역작업  철골자재(데크플레이트(슈퍼데크))를 화물차에서 지게차로 하차 적재위치에 내려놓는 중...
# 2   없음         기타  2022년04월27일 오전07시20분경 보라동 근린생활시설 및 다세대주택 신축공사 ...
# 3   없음       설치작업  2022.04.22 금요일 09시 10분경 202동 10호 다용도실에서 전기작업을 ...
# 4   없음         기타  일용근로자인 김**씨는 2022년 04월 20일 (수요일) 오전 06시57 분경에 ...
# 5   없음       해체작업  외부 비계해체작업 준비 중 작업자(비계공)가 3층 계단창을 통해 비계 및 작업발판으...
#
#                  사고원인                                           구체적 사고원인  \
# 1                 부주의             받침대 설치 시 측면에서 설치를 해야하나 지게차 앞에서 받침대를 설치
# 2                  기타  신축공사 현장 내 대기실에서 작업 착수 전 동료들과 모여 대기중 송**이 갑자기 쓰...
# 3                  기타                               현장 정리정돈 미흡 및 근로자 부주의
# 4                  기타                                 개인 질병(심근경색)에 따른 사고
# 5  복장, 개인보호구의 부적절한 사용  안전고리 체결 후 작업준비가 이루어져야 했으나 안전고리 미체결 등으로 사고가 발생한...
#
#    사망자수  부상자수 공종대분류 공종소분류 객체대분류   객체소분류    시설장소  \
# 1     1     0    건축  철골공사  건설자재  데크플레이트  근린생활시설
# 2     1     0    기타    기타    질병      질병    공동주택
# 3     1     0    건축  가설공사   가시설     거푸집      기타
# 4     1     0    기타    기타    질병      질병    부지조성
# 5     1     0    건축  가설공사   가시설    작업발판    단독주택
#
#                             위치장소                           부위위치 사고원인분류 사고원인분류2
# 1                             외부                             하역     사람     부주의
# 2  작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망  작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망     기타      기타
# 3                             내부                          상부(위)     기타      기타
# 4                             내부                          상부(위)     기타      기타
# 5                             외벽                             고소     사람     부적절

# %%
fig = plt.figure(figsize=(10,10))

case['사고원인분류2'].value_counts().plot.pie(autopct = '%1.1f%%', shadow = True)
plt.title('pie plot')

plt.show()

# %% [markdown]
# # **2. 공종**
# ---

# %%
case['공종대분류'].unique()
# Out:
# array(['건축', '기타', '산업설비', '토목', '기계설비', '전기설비', '통신설비', nan],
#       dtype=object)

# %%
case['공종소분류'].unique()
# Out:
# array(['철골공사', '기타', '가설공사', '금속공사', '도장공사', '철근콘크리트공사', '해체 및 철거공사',
#        '건축 토공사', '기계설비공사', '조경공사', '관공사', '미장공사', '수장공사', '건축물 부대공사',
#        '전기설비공사', '토공사', '조적공사', '산업설비공사', '터널공사', '타일 및 돌공사', '창호 및 유리공사',
#        '교량공사', '목공사', '하천공사', '지붕 및 홈통공사', '말뚝공사', '방수공사', '도로 및 포장공사',
#        '항만공사', '지정공사', '관공사 부대공사', '지반조사', '강구조물공사', '철도 및 궤도공사',
#        '통신설비공사', '지반개량공사', '댐 및 제방공사', nan, '프리캐스트 콘크리트공사', '특수 건축물공사'],
#       dtype=object)

# %%
# '공종대분류' 기준으로 '공종소분류'의 갯수
grouped_kind = case['공종소분류'].groupby(case['공종대분류'])
grouped_kind.size()
# Out:
# 공종대분류
# 건축      6707
# 기계설비     419
# 기타      1548
# 산업설비     212
# 전기설비     313
# 토목      2708
# 통신설비       6
# Name: 공종소분류, dtype: int64

# %%
# '공종대분류' 비율
fig = plt.figure(figsize=(10,10))

case['공종대분류'].value_counts().plot.pie(autopct = '%1.1f%%', shadow = True)
plt.title('pie plot')

plt.show()

# %%
const_kind = grouped_kind.unique().reset_index()
const_kind
# Out:
#   공종대분류                                              공종소분류
# 0    건축  [철골공사, 가설공사, 금속공사, 도장공사, 철근콘크리트공사, 건축 토공사, 조경공...
# 1  기계설비                          [기계설비공사, 해체 및 철거공사, 가설공사]
# 2    기타                                               [기타]
# 3  산업설비                          [해체 및 철거공사, 산업설비공사, 가설공사]
# 4  전기설비                          [전기설비공사, 가설공사, 해체 및 철거공사]
# 5    토목  [철근콘크리트공사, 관공사, 가설공사, 토공사, 터널공사, 교량공사, 하천공사, 말...
# 6  통신설비                                           [통신설비공사]

# %%
const_kind.to_csv('2_3. 공종 리스트.csv')

# %% [markdown]
# # **3. 객체대분류, 객체소분류**
# ---

# %%
case['객체대분류'].unique()
# Out:
# array(['건설자재', '질병', '가시설', '건설공구', '시설물', '건설기계', '기타', '부재', '토사 및 암반',
#        nan], dtype=object)

# %%
case['객체소분류'].unique()
# Out:
# array(['데크플레이트', '질병', '거푸집', '작업발판', '자재', '사다리', '건물', '굴착기',
#        '고소작업차(고소작업대 등)', '기타', '덕트', '파형강판', '흙막이가시설', '비계', '콘크리트펌프',
#        '전주, 전선', '기중기(이동식크레인 등)', '공구류', '벽이음', '배관', '타워크레인', '철골부재',
#        '담장', '강관동바리', '철근', '가설계단', '볼트', '지게차', '콘크리트믹서트럭', '벽체',
#        '시스템동바리', '슬래브', '개구부', '천공기', '기타 가시설', '파이프서포트', '핀', '절토사면',
#        '버팀보', '건설폐기물', '낙하물방지망', '와이어로프', '안전시설물', '특수거푸집(갱폼 등)', '지하매설물',
#        '지지대', '지반', '공기압축기', '항타 및 항발기', '작업대차', '석축', '경사면', '암사면',
#        '잭서포트', '버팀대', '차량', '거더', 'PSC빔', '옹벽', '성토사면', '창호', '덤프트럭',
#        '특수건설기계', '복공판', '띠장', '수평연결재', '콘크리트뱃칭플랜트', '엄지말뚝', '콘크리트피니셔',
#        '선라이트', '어스오거', '부석', '굴착사면', '천정패널', '아스팔트살포기', '터널 갱구부', '교각 기초',
#        nan, '지하벽체', '브라켓', '준설선', '전도방지재', '체인블럭', '로더', '지주가설재', 'RCS발판',
#        '보강토 옹벽', '몰탈혼합기', '롤러', '비산물', '철망', '벽돌', '레일', '터널 막장면',
#        '위험물저장탱크', '안전핀', '불도저', '가물막이', '트러스', '유증기', '돌담', '가설도로',
#        '슬레이트', '방음벽', '기성말뚝', '모터그레이더', '교량 바닥판', '조적벽체', '터널 천단부',
#        '콘크리트살포기', '방호선반', '노상안정기', '강박스', '교대 기초', '현장타설말뚝'], dtype=object)

# %%
# '객체대분류' 기준으로 '객체소분류'의 갯수
object = case['객체소분류'].groupby(case['객체대분류'])
object.size()
# Out:
# 객체대분류
# 가시설        3442
# 건설공구       1243
# 건설기계       1002
# 건설자재       2100
# 기타         1934
# 부재          554
# 시설물         523
# 질병          144
# 토사 및 암반     269
# Name: 객체소분류, dtype: int64

# %%
# '객체대분류' 비율
fig = plt.figure(figsize=(10,10))

case['객체대분류'].value_counts().plot.pie(autopct = '%1.1f%%', shadow = True)
plt.title('pie plot')

plt.show()

# %%
accd_object = object.unique().reset_index()
accd_object
# Out:
#      객체대분류                                              객체소분류
# 0      가시설  [거푸집, 작업발판, 흙막이가시설, 비계, 벽이음, 강관동바리, 가설계단, 시스템동...
# 1     건설공구                                  [사다리, 공구류, 몰탈혼합기]
# 2     건설기계  [굴착기, 고소작업차(고소작업대 등), 콘크리트펌프, 기중기(이동식크레인 등), 타...
# 3     건설자재  [데크플레이트, 자재, 덕트, 파형강판, 철근, 볼트, 파이프서포트, 핀, 와이어로...
# 4       기타     [기타, 전주, 전선, 건설폐기물, 지하매설물, 작업대차, 차량, 비산물, 유증기]
# 5       부재  [배관, 철골부재, 벽체, 슬래브, 개구부, 거더, PSC빔, 교각 기초, 트러스,...
# 6      시설물  [건물, 담장, 석축, 옹벽, 터널 갱구부, 보강토 옹벽, 위험물저장탱크, 돌담, ...
# 7       질병                                               [질병]
# 8  토사 및 암반  [절토사면, 지반, 경사면, 암사면, 성토사면, 부석, 굴착사면, 벽돌, 터널 막장...

# %%
accd_object.to_csv('2_4. 사고객체 리스트.csv')

# %% [markdown]
# # **4. 시설장소, 위치장소**
# ---

# %%
case['시설장소'].unique()
# Out:
# array(['근린생활시설', '공동주택', '기타', '부지조성', '단독주택', '제철공장', '공장', '하수도',
#        '창고시설', '교육연구시설', '제방(통관/호안)', '업무시설', '운동시설', '노유자시설', nan,
#        '종교시설', '철도터널', '보', '숙박시설', '수련시설', '문화 및 집회시설', '도로', '간척매립',
#        '교정 및 군사시설', '자동차 관련시설', '의료시설', '도로교량', '지하차도', '방송통신시설', '운수시설',
#        '도로터널', '환경오염방지시설', '지하철', '일반 및 고속철도', '계류시설', '판매시설', '수문/통문',
#        '석유화학공장', '상수도', '동물 및 식물 관련시설', '옹벽', '위험물 저장 및 처리시설', '호안',
#        '방파제', '하수처리시설', '절토사면', '용수전용댐', '철도교량', '묘지관련시설', '공공폐수처리시설',
#        '소각장', '관개수로', '수처리설비시설', '배수펌프장', '관광 휴게시설', '위락시설', '장례시설',
#        '중수도/하폐수처리수 재이용시설', '갑문', '다목적댐', '파제제', '복개구조물', '홍수전용댐'],
#       dtype=object)

# %%
case['위치장소'].unique()
# Out:
# array(['외부', '작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망', '내부', '외벽', '옥상', '인접주변',
#        '현장 밖 임차 현장사무실', 'PIT층 외벽', '북측 매립지 2구역', '현장내(지하6층)', '진입로(램프)',
#        '지붕', '외부 주행로', '기초바닥타설', '인근 현장사무소', '현장내', '농업용수로 매설부(C3)',
#        '108동 1단 낙하물 방지망', '공사현장 출입구', '도로 포장 지점(부안읍 학동길)', '2층에서1층으로추락',
#        '저수지(권양기) 인근', '강진군 칠량면 영동리1075-1', '밴트', '현장 내 철근작업장', '기초 바닥',
#        '공사현장 내부', '현장사무실', '현장 시험실 콘테이너 내부', '공사현장 내', '지반토공사현장',
#        '106동 주차장', '부잔교호안', '4.5 박스 작업장에서', '건물 입구', '103동 인근', '철골작업중',
#        '정거장 인근 개착부 줄파기', '하자포리 4-6', '종점부', '안전가설설치 및 해체', '귀', '기초',
#        '지하2층 합벽', '현장 3구간 워킹타워 주변', '코로나19 확진', '생물반응조 설치 현장',
#        '103동 지상4층', '주차장 슬라브', '용접작업장', '가물막이', '지상8층 옥상', '내부 3층 엘리베이터',
#        '환기구#3 B/P장', '109동 10층 바닥', '콘크리트블록 상단', '기초 파일공사', 'T/C 운반장소',
#        '파일 야적장', '덕진구 전당길24', '측구', '줄파기 작업구간', '말뚝 기초부', '거더 상부', '105동',
#        '맨홀외부 천공작업', '주차장 공사현장', '거더제작장', '충남 서천군 장항읍 화천리 219-1',
#        '지하층 터파기공사 중', '기계식주차장 비계', '사동리 72-1 배수지', 'PC거더 제작장', '지상3층 계단실',
#        '현장사무실 교육장', '공사용가도', '현장 내', '침사지 조성 후 보양천막 고정 작업', '현장사무실 앞',
#        '102동 1층 필로티', '관로공사구간', '바닥', '지붕(박공지붕에서 옥상통로로)', '103동 지하1층',
#        '도로절삭구간', '가교', '장동역사 2층', '슬래브', '주차장', '제작장', '화북면 자천리 일원',
#        '고속도로 성토부', '공사구간 내 차정교', '철근 가공장', '사유지', '준설선', '공사용 가도 지면',
#        '가시설/육교하부 가설방음벽 제작장', '본법공원 생태공원 공사 부지', '토목현장', '112동 파일공사 작업장',
#        '터파기사면', '도로확장공사구간', '인천검단  RC3BL 합성버팀보 1-2구간', '이동 간 도로', '성토사면',
#        '테트라네오 제작장', '305동 주변 지하주차장', '해양작업선', '현장 외부 컨테이너',
#        '보도육교#26 납측 교대부', '대전 서구 괴곡동 397-2', '활주로 재포장 공사구역 내(N4인근)',
#        '아파트 측면 녹지', '대로3-10부근', '교량 하부', '하천 교량 상부 작업 중', '식당',
#        '제방구간 연약지반', '송파동 42-3(CIP 작업장)', '측점 5+040(우, 지방도 887호선)',
#        '대로 3-10 NO. 20 부근', '야적장', '해측 외벽 면보수', '선박', '해상파이프렉',
#        '굴착부 이동 안전계단', '2층 복도', '공사중인 지방도 887호선', '지상3층 바닥', '지하층', '계단실',
#        '바닥부', '현장 내 건물 외부', '작업현장', '공동구 5-2구간 구조물 내부', '105동 지상주차장 부근',
#        '클럽하우스 1층', '107동 옥상', '지하주차장 입구', '방파제/파라펫', '보수공사', '지하철 환기구',
#        '2층 바닥', '106동 옥탑', '해상교량', '고속도로 램프 소분리대', '나대지', '지하주차장 저수조',
#        '지상 5층 바닥 위', '합벽', '브라켓 제작장', '10동 외벽', '2층 보 형틀',
#        '현장내 2506동 주변 외부', '비상계단', '지하주차장 램프 구간', '시스템비계 작업발판 상부',
#        '식생호안블록', '자재창고', '우수암거 슬라브', '철근가공장', '다대중학교 정문', '작업구 밖',
#        '덤프트럭 적재함', '지하차도 기초부', '크랏샤장', '외부 지상부',
#        '공사현장 외 타지역(강릉)에 소재한 작업장', '없음', '작업장 외부 이면도로', '소파블록 제작장',
#        'HDPE Purification Area', '보도와 차도 경계부', '시설바닥', '현장부지 외 택지개발지구',
#        '하도급사 가설사무실 축조공사장', '북리 농로 일원', '동 지하3층', '가설방음벽', '101동 앞 주차장 구간',
#        '현장옥상바닥', '103동 주변 1층 바닥', '103동 지하1층 피트층 구간', '방수로', '데크설치 작업장소',
#        '주차장내', '마무리 포장작업', 'PKG-3 Compressor Shelter', '타워크레인 내부', '계단부',
#        '최상층 외부', '공사장과 떨어진 외부공간', '게이트1 주변 현장', '지하1층 램프구간', '부채도로',
#        '현장 외 차고지 창고', '109동', '정문 게이트 옆', '동 지하2층', '지하차도 슬라브',
#        '교량 하부 A1 법면구간', '교량(설계교) A1 법면 하부', '사면', '자재야적장', 'v형 측구 조립 작업장',
#        '토사 선별장비 상부', '지하흙막이 합벽구간', '배수지', '블록제작장 내',
#        '현장외 퇴근중 교통사고(버으내교차로)', '블록제작장', '903동 동출입구 앞', '지하5층',
#        '주차장입구 램프구간', '현장내 단지 외각부', '지상1층', '교량 슬라브 상판', '나주 노안지구 공사현장',
#        '지상2층 6번코어 주변', '비계 이동 통로', '잔재물 이동 처리 중', '중로 pc박스', '보일러동 1층',
#        '승강장 상부', '주민공동시설 3층부', '주차장 바닥', '1501동 18층 4호 주방', '교대 하부',
#        '장시간 작업한 곳', '외곽통로', '자재 적치장', '외부 2층 슬라브', '프리필터', '포장공사 구간 시점부',
#        '흙막이 가시설 설치구간', '정문 GATE 경비실 옆', '타워', '후면', '근로자 식당 앞 주차장',
#        '1층바닥슬라브', '냉각탑 pit 출입구', '굴착기 위', '컨테이너화장실', '도로 굴착사면',
#        '114~115동 사이 우각부', '108동 9층(재해자 주장)', '주철관 외부', '블럭놓기전 사석고르기',
#        '지상5층', '지상층 캐노피', '보강토 옹벽 위 4.0m', '7번지주 앞 경사로', '가설작업 중',
#        '거더 제작장', '현장 외부 야적장', '터빈동 2층 내부', '수리티터널', '코핑 상부',
#        '102동 주변 램프구간', '포스코현장 내 101동 주변', '골조타설 중 양수기 호스 위치',
#        '1층 바닥 보 거푸집 조립 진행(당일작업 완료)', '7호 옹벽 벌목 구간', '공사현장과 분리된 외부주차장',
#        '고속도로변', '1층 필로티 외부비계', '서측 출입구', '개인질병', '평촌교 방호벽', '현장전면 1층 출입구',
#        '지하 2층', '현장', '여수로', '지하주차장1층', '공사장 내부', '철근야적장',
#        '하수처리시설 증설부위 기초부위', '지하주차장 1번 램프', '수중부', '교사동 배면동 1층 시스템비계',
#        '공사장 3층바닥', '출입구 바닥', '현장 인근', '지상4층', '지하주차장B1F 바닥',
#        '2층 계단옹벽 철근배근', '장흥정거장  구내 배수로', '축도', '단지 내 외부', '105동 외부',
#        'LDPE 구간', '교사동 전면동 지층', '1층', '하부', '보령시 남포면 양향리 270-3 도로',
#        '굴착법면', '노상', '기타', '불특정', '공사작업 구간 내', '공사장내 철근가공장',
#        '현장게이트 앞(외부)', '물량장 바지선', '신축부지 중앙부', '지하주차장 1층', '지상층 바닥', '이면도로',
#        '모노레일 운행구간', '지하2층', '지상', '현장내 야적장', '작업장', '굴착사면', '지하층 기계식주차장',
#        '거푸집 해체', '동 기초', '지상1층 복공판', '현장 안', '용수개거에서 자재정리', '옥상캐노피',
#        '맨홀펌프장 주변 가시설', '대양면 백암리', '장지동 692-63', '해암3터널', '공사완료후 이동해체작업장소',
#        '부지경계', '402동 1층 호이스트 앞', '기계실 D/A', '주차타워 지붕', '주차장 보 슬래브',
#        '작업발판', '무용관동 1층 주변', '외곽 가설 울타리', '지선관로공사 굴착부분', '배수암거', '3번게이트',
#        'LNG탱크 건설사업장 내', '근골격계 질환 특정장소 지정할수 없음', '내부와 비계 사이',
#        '102동 1,2라인 출입구', '비상램프', '101동 근생 옥상', '통합밸브실 주변', '현장출입구(경비실옆)',
#        '철근배근 상부', '활성탄흡착지 지하배관실', '역사 기존시설', '터널 내부', '공사현장내',
#        '내,외부 파악불가', '배수터널/외부', '용수로', '구포동 720 일원 도로개설구간', '암롤박스 내부',
#        '근린생활시설 1층', '기계식 주차장', '버림 거푸집 조립', '지하2층 BT비계 위', '교육동 1층 거푸집작업',
#        '1층벽체 조립중', '가설울타리', '처리장 내부(처리조)', '흙막이가시설3단', '무용관동 지상2층',
#        '세륜기 주변', '구조물', '현장 출근을 위한 주변 도로', '터파기 현장 내부', '바닥 슬래브',
#        '흙막이용 h-heam 반출/상차작업', '문주', '건축물  기초 파일항타부', '기초작업', '토공작업구간',
#        '현장식당 부근', '항타기 옆', '터파기현장', '교육동', '현장내 (터파기)', '지하2층 바닥',
#        '지하1층 램프입구 측', '부속건물(수선공사)', '지하', '해당없음', '사업현장 내 느티나무',
#        '의령읍 무전리 산31-2', '캐노피 상부', '상가구간 상부', '현장 정문', '흙막이벽체 2단 띠장',
#        '지하주차장바닥', '현장사무실 앞 휴게공간', '공원 현장 내', '현장내부', '101동 1층~41층',
#        '작업 현장 내부', '지하2층 바닥면', 'C.I.P 파일천공', '공사지역 외(협력업체 사무소 인근)',
#        '근로자 식당 내', '방파제 상부', '104동', '공장내부 3층', '확인불가', '가설계단', '지하주차장',
#        '가시설', '불등지하차도', '공구실', '교댜', '지하층 상부 슬라브', '상주시 냉림동 125-19', '수중',
#        '사무실 주변', '철골구조체', '가설사무소앞', '현장야적장', '암거시공구간내', '102동 커뮤니티센터 PIT',
#        '경산시 계양동 297-2번지 남매근린공원 일원', '현장 내 철근 가공장', '지하주차장 파일 작업구간',
#        '103동 지상5층', '분류불능', '남산예장자락 외부 현장', '102동 지상6층', '물양장 위 물탱크 내부',
#        '외부야적장', '지하주차장 기초', '2단자 201동 주변', '공동주택 102동', '1공구 Ramp-E추진기지',
#        '외부 자재야적장', '3~4층 계단실', '107동 주차장', '생극면 차곡리 83-1', '굴착저면',
#        '현장내 폐기물야적장', '201동 옥상배수로 5-6라인', '지하4층', '1202동 주변주차장 지하2층',
#        '바닥기초 설치작업 현장', 'Coal Shed 입구', '연약지반처리공법 작업 중', 'Pipe rack 상부',
#        '포상진지', '터널', '주차장 램프', '현장 진입로(일반도로)', '교각부', '2구간 슬라브 상부',
#        '절토비탈면 소단',
#        '경기도 안산시 **구 **동 소재 ****㈜ 시화멀티테크로밸리 제4공구 조성공사 현장 중 DCM 작업장',
#        '반포동 725-5 앞 도로', '작업장 입구', '단지내 멘홀', '하천 제방', '대로3-7/NO.8(좌측)',
#        '터빈1호기', '현장 사무실', '차량적재함', '밸브실', '관로터파기 내부', '터널/내부', '옥상층',
#        '광주광역시 광산구 월전동 121 인근', '지상4층 1구간', '103동 주차장', '1층거푸집작업',
#        '자재 야적장', '내부 출입구 벽체', '포디움 내부', 'PC BOX 자재 상부', '신설구조물내부', '보도',
#        '맨홀', 'rectcle gas 구조물/ 바닥', '오수관로  터파기 구간', '병곡면 월암리 망월마을입구',
#        'A2BL 204동 지하1층 엘리베이터 홀', '사업장 내', '배수로', '현장사무실 앞 철근가공장',
#        '공동주택 건설현장 내부', '당월리 해상', '가드레일 내측', '3층', '아파트 동주변', '봉덕리 448-1',
#        '동측 부대토목 구간', '교량 빔 하단', '지하주차장 내부', '저수지 제당', '환기구 내부', '근로자 휴게실',
#        '신김천대교', '아파트 세대 내부', '1702동 슬라브', '호남선 97.8k(순천) 길어깨부', '고속도로내',
#        '해남터널 시점부', '평야부', '지하3층', '파라펫 거푸집 설치', '도로(교차로)', '동해항15번선석',
#        '108동 상부', '바닥슬래브', '골조바닥', '시스템 비계설치 후 이동', '관리사무소',
#        '타워크레인 운전석 이동중', '교각 기초', '정문출입구 게이트내부', '공사장 안', '원형램프',
#        '101동 1층 호이스트 앞', '독립기초', '102동 6번계단실', '지하층 벽체철근조립장', '교량 상판',
#        '105동 앞 외부', '진입로', '옥상 파라펫', '사업부지주위 가설휀스설치', '화성JCT R-A',
#        '슬래브 난간부', '104동 가설도로', '맨홀상부', '신규투기장', '지하1층', '맨홀내부',
#        '강원도 화천군 간동면 오음리 376-1(오음1가압장) 현장', '얕은구간', '구내도로', '터파기 지반',
#        '보행캐노피', '교각', '내부 벽체', '현장 근로자 화장실', '현장주변', '갓길 측',
#        '일과 후 현장사무실에서 휴식 중 사망', '101동 2층', '지하1층 B구간',
#        '충북 청주시 상당구 미원면 중리 22-7', '대구광역시 수성구 고모로 33길 100(오성복지회관 인근)',
#        '도장공장', '그라우트 밀크 믹싱기', '하부공', '옹벽', '사천면 중앙동로 43', '게이트 앞', '출입문',
#        '정문', '102동 지하1층 주차장', 'E/V PIT 내부', '사업부지', '지상4층 바닥', '동방파제',
#        '현장 경계 울타리 밖', '굴착단면', '시스템비계', '2층 계단실', '강진1터널 터널 내부', 'TBM장',
#        '평동B함', '2층 바닥 슬라브', '인접 변압기', '댐 배면', '대로3-35호선', '교각 가시설',
#        '현장 내부', '타워5호기 앞', 'T-207 Bottom Slab', '질병', 'U형측구', '경사면',
#        '607동 지하주차장', '관 부설 부위', '610~12동 사이 데크 작업구간', '3번타워15.5M 지점',
#        '지하층 버팀보', '현장 밖 현장사무실', '에리베이터', '110동 지하주차장 1층 동 pit내',
#        '협력사 현장사무실 배전반', '임시야적장', '인근 식당', '4동 주변 주차장 슬라브', nan,
#        '삼성디스플레이 아산1캠퍼스 8-1L, E4 반입구외부', '지상1층 C구간', '은행업무 외근', '부지내',
#        '지하층 내부', '수직구', '저수조 내부', '갱문 상부', '철탑', '4단 띠장해체중 추락사고',
#        '1번 게이트 주변', '지상 1층 출입구', '2층 휴게공간', '8동 1층 발코니', '좌측면 코너스트러트',
#        '불분명', '세대 슬라브', '도로 밖 별도 작업 공간', '109동 1층', '질병성', '현장사무실 자재야적장',
#        '1층화장실', '4동 주변 주차장', '외부 담장옹벽', '개인 질병', '토공사', '101동 앞 주차장',
#        '여좌지구 공사현장 내', '길내기#5', '질병성 재해로 분류불능', '옥상바닥', '운반차량 적재함',
#        '가시설 버팀대 작업', '본인자택', '코너 STRUT', '아침조회장', '302동 2,3층 계단',
#        '201동 3층 1-3호 라인 PD주변', '2307동 후면 조경식재 구간', '장비수리', 'SK판넬 내부',
#        '흙막이 가시설 설치 부분', '천정 전등작업', '경비실', '오피스텔', '교량기초', '청우중공업(주)',
#        '현장 출입구', '지하층 옹벽', '계단', '1층바닥', '지상1층 보측면', '터빈동 1호기', '사다리',
#        '교육장', '현장 외부 식당가는 경로', '2층 바닥슬라브', '불명확', '주 줄입구', '102동 시스템비계'],
#       dtype=object)

# %%
# '시설장소' 기준으로 '위치장소'의 갯수
location = case['위치장소'].groupby(case['시설장소'])
location.size()
# Out:
# 시설장소
# 간척매립           8
# 갑문             2
# 계류시설          30
# 공공폐수처리시설      14
# 공동주택        3387
#             ...
# 하수도          305
# 하수처리시설        50
# 호안            19
# 홍수전용댐          1
# 환경오염방지시설      19
# Name: 위치장소, Length: 62, dtype: int64

# %%
# '시설장소' 비율
fig = plt.figure(figsize=(10,10))

case['시설장소'].value_counts().plot.pie(autopct = '%1.1f%%', shadow = True)
plt.title('pie plot')

plt.show()

# %%
location_list = location.unique().reset_index()
location_list
# Out:
#         시설장소                                               위치장소
# 0       간척매립               [북측 매립지 2구역, 준설선, 제방구간 연약지반, 외부, 내부]
# 1         갑문                                          [외부, nan]
# 2       계류시설  [인접주변, 외부, 콘크리트블록 상단, 내부, 해양작업선, 블록제작장 내, 제작장,...
# 3   공공폐수처리시설                     [내부, 외부, 지하1층 램프구간, 인접주변, nan]
# 4       공동주택  [작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망, 옥상, 내부, 외부, 현장...
# ..       ...                                                ...
# 57       하수도  [외부, 인접주변, 내부, 도로 포장 지점(부안읍 학동길), 생물반응조 설치 현장,...
# 58    하수처리시설                [내부, 인접주변, 외부, 세륜기 주변, 현장 사무실, nan]
# 59        호안  [종점부, 외부, 인접주변, 내부, 당월리 해상, 동해항15번선석, 신규투기장, 얕...
# 60     홍수전용댐                                               [외부]
# 61  환경오염방지시설   [외부, 지하철 환기구, 프리필터, 내부, 인접주변, 바닥기초 설치작업 현장, nan]
#
# [62 rows x 2 columns]

# %%
location_list.to_csv('2_5. 장소 리스트.csv')

# %% [markdown]
# # **5. 부위**
# ---

# %%
print(case['부위위치'].unique())
print(len(case['부위위치'].unique()))
# Out:
# ['하역' '작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망' '상부(위)' ... '출입문 개폐' '현장내' '방지망 파이프']
# 1208

# %%
# '부위내용(=객체소분류)' 기준으로 '부위위치'의 갯수
part = case['부위위치'].groupby(case['객체소분류'])
part.size()
# Out:
# 객체소분류
# PSC빔          7
# RCS발판         2
# 가물막이          1
# 가설계단         92
# 가설도로          8
#            ...
# 파형강판          5
# 핀            38
# 항타 및 항발기     82
# 현장타설말뚝        1
# 흙막이가시설      257
# Name: 부위위치, Length: 114, dtype: int64

# %%
# '객체소분류' 비율
fig = plt.figure(figsize=(10,10))

case['객체소분류'].value_counts().plot.pie(autopct = '%1.1f%%', shadow = True)
plt.title('pie plot')

plt.show()

# %%
part_list = part.unique().reset_index()
part_list
# Out:
#         객체소분류                                               부위위치
# 0        PSC빔                   [하부(아래), 거더 강연선 정착대, 상부(위), nan]
# 1       RCS발판                                               [바닥]
# 2        가물막이                                               [바닥]
# 3        가설계단  [바닥, 지하, 가설계단에서, 고소, 상부(위), 하부(아래), 옥상계단발판하부, ...
# 4        가설도로                                  [앞, 지하차도 입구, nan]
# ..        ...                                                ...
# 109      파형강판                                [하부(아래), 바닥, 상부(위)]
# 110         핀  [바닥, 101동 6층 계단실, 옆, 앞, 지하, 핀이 튐, 하부(아래), 고소, ...
# 111  항타 및 항발기  [옆, 조종석 옆 발판, 리더옆, 하부(아래), 바닥, 철근망 관입중 끼임, 앞, ...
# 112    현장타설말뚝                                               [바닥]
# 113    흙막이가시설  [바닥, 상부(위), 지하, 근처, 코너스트러트 위, 옆, 토류판 설치 인근, 뒤,...
#
# [114 rows x 2 columns]

# %%
part_list.to_csv('2_6. 부위 리스트.csv')

# %% [markdown]
# # **6. 시설물 종류**
# ---

# %%
# 세부적으로 컬럼 분할
case['시설물 대분류'] = case['시설물 종류'].str.split(' - ').str[0]
case['시설물 중분류'] = case['시설물 종류'].str.split(' - ').str[1]
case['시설물 소분류(상세)'] = case['시설물 종류'].str.split(' - ').str[2]

case['시설물 소분류'] = case['시설물 소분류(상세)'].str.split('(').str[0]

# 분할한 '시설물 종류' 컬럼은 제거
case = case.drop(['시설물 종류'], axis = 1)

case.head()
# Out:
#                                            사고명                     기상상태  \
# 1                           외남동162 근린생활시설 신축공사  날씨 : 맑음기온 : 23℃습도 : 20%
# 2  보라동 391-23 근린생활시설 및 다세대주택 신축공사 작업 착수 전 사망사고  날씨 : 흐림기온 : 22℃습도 : 50%
# 3                        송산그린시티 EB4블록 형틀공 추락사고  날씨 : 흐림기온 : 15℃습도 : 74%
# 4                             화성비봉 공공주택지구 조성공사  날씨 : 맑음기온 : 15℃습도 : 51%
# 5                         상도동 243-19 신축공사 추락사고  날씨 : 흐림기온 : 19℃습도 : 25%
#
#                     인적사고 물적사고     작업프로세스  \
# 1                 물체에 맞음   없음  상차 및 하역작업
# 2                     질병   없음         기타
# 3                     찔림   없음       설치작업
# 4                     질병   없음         기타
# 5  떨어짐(5미터 이상 ~ 10미터 미만)   없음       해체작업
#
#                                                 사고경위                사고원인  \
# 1  철골자재(데크플레이트(슈퍼데크))를 화물차에서 지게차로 하차 적재위치에 내려놓는 중...                 부주의
# 2  2022년04월27일 오전07시20분경 보라동 근린생활시설 및 다세대주택 신축공사 ...                  기타
# 3  2022.04.22 금요일 09시 10분경 202동 10호 다용도실에서 전기작업을 ...                  기타
# 4  일용근로자인 김**씨는 2022년 04월 20일 (수요일) 오전 06시57 분경에 ...                  기타
# 5  외부 비계해체작업 준비 중 작업자(비계공)가 3층 계단창을 통해 비계 및 작업발판으...  복장, 개인보호구의 부적절한 사용
#
#                                             구체적 사고원인  사망자수  부상자수  ... 공종소분류  \
# 1             받침대 설치 시 측면에서 설치를 해야하나 지게차 앞에서 받침대를 설치     1     0  ...  철골공사
# 2  신축공사 현장 내 대기실에서 작업 착수 전 동료들과 모여 대기중 송**이 갑자기 쓰...     1     0  ...    기타
# 3                               현장 정리정돈 미흡 및 근로자 부주의     1     0  ...  가설공사
# 4                                 개인 질병(심근경색)에 따른 사고     1     0  ...    기타
# 5  안전고리 체결 후 작업준비가 이루어져야 했으나 안전고리 미체결 등으로 사고가 발생한...     1     0  ...  가설공사
#
#   객체대분류   객체소분류    시설장소                           위치장소  \
# 1  건설자재  데크플레이트  근린생활시설                             외부
# 2    질병      질병    공동주택  작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망
# 3   가시설     거푸집      기타                             내부
# 4    질병      질병    부지조성                             내부
# 5   가시설    작업발판    단독주택                             외벽
#
#                             부위위치 시설물 대분류 시설물 중분류  \
# 1                             하역      건축     건축물
# 2  작업 착수 전 대기중에 쓰러져 병원으로 이송하여 사망      건축     건축물
# 3                          상부(위)      건축     건축물
# 4                          상부(위)      토목      기타
# 5                             고소      건축     건축물
#
#                             시설물 소분류(상세) 시설물 소분류
# 1  근린생활시설(연면적 : 455.46㎡, 지상 2층, 지하 0층)   근린생활시설
# 2    공동주택(연면적 : 709.85㎡, 지상 5층, 지하 0층)     공동주택
# 3   기타(연면적 : 24,161.30㎡, 지상 3층, 지하 1층)       기타
# 4                                  부지조성    부지조성
# 5    단독주택(연면적 : 284.06㎡, 지상 4층, 지하 1층)     단독주택
#
# [5 rows x 21 columns]

# %%
case['시설물 대분류'].unique()
# Out:
# array(['건축', '토목', '산업환경설비', '조경'], dtype=object)

# %%
case['시설물 중분류'].unique()
# Out:
# array(['건축물', '기타', '산업생산시설', '상하수도', '하천', '발전시설', '터널', '도로', '교량',
#        '공동구', '환경시설', '항만', '옹벽 및 절토사면', '철도', '댐', '공원', '숲', '생태공원',
#        '정원', '수목원'], dtype=object)

# %%
case['시설물 소분류'].unique()
# Out:
# array(['근린생활시설', '공동주택', '기타', '부지조성', '단독주택', '제철공장', '공장', '하수도',
#        '창고시설', '교육연구시설', '제방', '업무시설', '운동시설', '노유자시설', '', '종교시설',
#        '철도터널', '보', '숙박시설', '수련시설', '문화 및 집회시설', '도로', '간척매립',
#        '교정 및 군사시설', '자동차 관련시설', '의료시설', '도로교량', '지하차도', '방송통신시설', '운수시설',
#        '도로터널', '환경오염방지시설', '지하철', '일반 및 고속철도', '계류시설', '판매시설', '수문/통문',
#        '석유화학공장', '상수도', '동물 및 식물 관련시설', '옹벽', '위험물 저장 및 처리시설', '호안',
#        '방파제', '하수처리시설', '절토사면', '용수전용댐', '철도교량', '묘지관련시설', '공공폐수처리시설',
#        '소각장', '관개수로', '수처리설비시설', '배수펌프장', '관광 휴게시설', '위락시설', '장례시설',
#        '중수도/하폐수처리수 재이용시설', '갑문', '다목적댐', '파제제', '복개구조물', '홍수전용댐'],
#       dtype=object)

# %%
case['시설물 소분류(상세)'].unique()
# Out:
# array(['근린생활시설(연면적 : 455.46㎡, 지상 2층, 지하 0층) ',
#        '공동주택(연면적 : 709.85㎡, 지상 5층, 지하 0층) ',
#        '기타(연면적 : 24,161.30㎡, 지상 3층, 지하 1층) ', ...,
#        '교육연구시설(연면적 : 1,688㎡, 지상 3층, 지하 1층) ',
#        '근린생활시설(연면적 : 1,179.49㎡, 지상 4층, 지하 0층) ',
#        '교육연구시설(연면적 : 5,224.42㎡, 지상 4층, 지하 1층) '], dtype=object)

# %%
# '시설물 대분류, 시설물 중분류' 기준으로 '시설물 소분류'의 갯수
facility = case['시설물 소분류'].groupby([case['시설물 대분류'], case['시설물 중분류']])
facility.size()
# Out:
# 시설물 대분류  시설물 중분류
# 건축       건축물          8672
# 산업환경설비   발전시설          327
#          산업생산시설        119
#          환경시설          114
# 조경       공원             37
#          기타             63
#          생태공원            4
#          수목원             2
#          숲               8
#          정원              5
# 토목       공동구             5
#          교량            247
#          기타            316
#          댐              40
#          도로            610
#          상하수도          597
#          옹벽 및 절토사면     109
#          철도            115
#          터널            217
#          하천            179
#          항만            135
# Name: 시설물 소분류, dtype: int64

# %%
facility_list = facility.unique().reset_index()
facility_list
# Out:
#    시설물 대분류    시설물 중분류                                            시설물 소분류
# 0       건축        건축물  [근린생활시설, 공동주택, 기타, 단독주택, 공장, 창고시설, 교육연구시설, 업무시...
# 1   산업환경설비       발전시설                                                 []
# 2   산업환경설비     산업생산시설                                   [제철공장, 석유화학공장, ]
# 3   산업환경설비       환경시설  [환경오염방지시설, 하수처리시설, 공공폐수처리시설, 소각장, 수처리설비시설, 중수도...
# 4       조경         공원                                                 []
# 5       조경         기타                                                 []
# 6       조경       생태공원                                                 []
# 7       조경        수목원                                                 []
# 8       조경          숲                                                 []
# 9       조경         정원                                                 []
# 10      토목        공동구                                                 []
# 11      토목         교량                            [도로교량, 철도교량, 기타, 복개구조물]
# 12      토목         기타                                     [부지조성, 간척매립, ]
# 13      토목          댐                           [용수전용댐, 다목적댐, 기타, 홍수전용댐]
# 14      토목         도로                                         [도로, 기타, ]
# 15      토목       상하수도                                     [하수도, 기타, 상수도]
# 16      토목  옹벽 및 절토사면                                     [기타, 옹벽, 절토사면]
# 17      토목         철도                               [지하철, 일반 및 고속철도, 기타]
# 18      토목         터널                           [철도터널, 지하차도, 도로터널, 기타, ]
# 19      토목         하천                    [제방, 보, 수문/통문, 기타, 관개수로, 배수펌프장]
# 20      토목         항만                     [기타, 계류시설, 호안, 방파제, 갑문, , 파제제]

# %%
facility_list.to_csv('2_7. 시설물 리스트.csv')

# %% [markdown]
# # **7. 작업 프로세스**
# ---

# %%
case['작업프로세스'].unique()
# Out:
# array(['상차 및 하역작업', '기타', '설치작업', '해체작업', '운반작업', '이동', '형틀 및 목공', '타설작업',
#        '준비작업', '굴착작업', '양중작업', '조립작업', '마감작업', '정리작업', '청소작업', '반출작업',
#        '연결작업', '적재작업', '설비작업', '인양작업', '도장작업', '절단작업', '정비작업', '고소작업',
#        '전기작업', '쌓기작업', '양생작업', '보수 및 교체작업', '매설작업', '벌목작업', '천공작업',
#        '항타 및 항발작업', '확인 및 점검작업', '부설 및 다짐작업', '용접작업', '거치작업', '물뿌리기 작업',
#        '측량작업', '절취작업', '장약 및 발파작업', '인발작업', nan, '철근조립작업', '자재정리', '장비이동',
#        '자재이동', '정지작업', '점검', '장비청소', '제거작업', '평탄작업', '철거작업', '작업장 출입',
#        '고정작업', '돌붙임 및 줄눈 작업', '수정작업', '다짐작업', '교체작업', '토사하역', '상차작업',
#        '전기배선작업'], dtype=object)

# %%
process_array = case['작업프로세스'].unique()
process = pd.DataFrame(data = process_array, columns = ['작업프로세스'])
process.head()
# Out:
#       작업프로세스
# 0  상차 및 하역작업
# 1         기타
# 2       설치작업
# 3       해체작업
# 4       운반작업

# %%
process.to_csv('2_8. 작업프로세스 리스트.csv')

# %%
case.to_csv('2. EDA_원인분석, 고유값.csv')
